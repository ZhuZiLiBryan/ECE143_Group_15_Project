# %%
# Imports for Milk Ratio visualizations
from eda_milk_ratio.eda_milk_ratio_main import eda_milk_main 

# Imports for Hour of Day Visualizations
from eda_Hours0fDay.eda_hours_main import eda_hourly_transactions_main

# Imports for Weekend, Weekday, Holiday visualizations
from eda_weekday_weekend import eda_sales_comparison, eda_popular_coffee_comparison, eda_order_value_statistics

# Imports for User Analysis visualizations
from user_analysis import show_feature_importance

# Imports for K-Means Visualizations
from kmeans.kmeans_main import kmeans_main

# Imports for Promotional Analysis Visualizations
from promotional_analysis.promotional_analysis_main import promotional_analsysis_main

# %% [markdown]
# # EDA For Hour of Day Basis Visualizations

# %%
eda_hourly_transactions_main()
# Out:
# Target data file: upload/index_1.csv
# Data loaded and preprocessed successfully.

# %% [markdown]
# # EDA For Milk Ratio Visualizations

# %%
eda_milk_main()
# Out:
# --------------------
# Plotting Average Milk Ratio by Hour
# --------------------
# --------------------
# Plotting Average Milk Ratio Heatmap
# --------------------

# %% [markdown]
# # EDA for Visualization Statistics of Weekend, Weekend, Holiday

# %%
eda_order_value_statistics()

# %%
eda_sales_comparison()

# %%
eda_popular_coffee_comparison()

# %% [markdown]
# # EDA for K-Means Clustering Visualization

# %%
kmeans_main()
# Out:
# Target data file: upload/index_1.csv
# Data loaded and preprocessed successfully.
# Cluster Analysis (Mean Values):
#          days_since_last_visit  total_visits  total_spent
# cluster
# 0                    96.282638      2.711978    86.154186
# 1                   269.907965      1.653097    53.382195
# 2                    71.500000     74.750000  2259.010000
#
# Customer Counts per Cluster:
# cluster
# 0    743
# 1    565
# 2      8
# Name: count, dtype: int64

# %% [markdown]
# # User Analysis Visualizations

# %%
show_feature_importance()

# %% [markdown]
# ## Promotional Analysis based on Rolling Averages Visualizations

# %%
promotional_analsysis_main()
# Out:
# Loading data...
# Data loaded: 3636 records
# Coffee types: {'Americano': 1402, 'Latte': 782, 'Hot Chocolate': 525, 'Cappuccino': 501, 'Cortado': 292, 'Espresso': 134}
#
# ...
# 1. Sales Prediction
# ...
# Predicted coffee sales for next day: 414.12
# ...
# 2. Most Popular Coffee Prediction
# ...
# Predicted most sold coffee for next month: Americano
# Predicted sales: 119.50
# Predicted most sold coffee for next week: Americano
# Predicted sales: 35.00
# ...
# 3. Daily Promotion Recommendations
# ...
# Recommended promotion drink per day (top 7 latest):
# 2025-03-17: Promote 'Cortado'
# 2025-03-18: Promote 'Cortado'
# 2025-03-19: Promote 'Cortado'
# 2025-03-20: Promote 'Latte'
# 2025-03-21: Promote 'Cortado'
# 2025-03-22: Promote 'Cortado'
# 2025-03-23: Promote 'Cortado'
#
# Last 14 days recommendations:
#            recommended_drink
# 2025-03-10           Cortado
# 2025-03-11           Cortado
# 2025-03-12           Cortado
# 2025-03-13           Cortado
# 2025-03-14           Cortado
# 2025-03-15             Latte
# ...
